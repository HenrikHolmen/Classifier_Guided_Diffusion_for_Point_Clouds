# %% [markdown]
# ### Importing training file

# %% [markdown]
# ### Plotting Coverage over iterations

# %%
import numpy as np
import matplotlib.pyplot as plt

# Coverage CD values from the provided file
coverage_cd_values = [
    0.375000, 0.400000, 0.390000, 0.390000, 0.397500, 0.417500, 0.427500,
    0.417500, 0.400000, 0.395000, 0.410000, 0.410000, 0.422500, 0.412500,
    0.430000, 0.440000, 0.420000, 0.415000, 0.417500, 0.415000, 0.417500,
    0.407500, 0.445000, 0.422500, 0.417500, 0.435000, 0.415000, 0.412500,
    0.395000, 0.427500, 0.402500, 0.412500, 0.467500, 0.445000, 0.430000,
    0.410000, 0.425000, 0.437500, 0.437500, 0.407500, 0.405000, 0.410000,
    0.410000, 0.422500, 0.432500, 0.387500, 0.425000, 0.417500, 0.445000,
    0.430000, 0.417500
]

# Generate iterations corresponding to the values (assuming 10000 iterations per value)
iterations = np.arange(10000, 510000+10000, 10000)

# Plot Coverage - CD with log scale for x-axis
plt.figure(figsize=(10, 5))
plt.plot(iterations, coverage_cd_values, marker='o', label='Coverage (CD)')
plt.xscale('log')
plt.xlabel('Iterations (log scale)')
plt.ylabel('Coverage (CD)')
plt.title('Validation Coverage Chamfer Distance Curve')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.savefig('Validation_Coverage_CD_curve_corrected_log.png' , dpi=500)
plt.show()

# %% [markdown]
# ### Plotting MinMatDis over iterations

# %%
import numpy as np
import matplotlib.pyplot as plt

# MinMatDis CD values from the provided file
minmatdis_cd_values = [
    0.037892, 0.035176, 0.034948, 0.034152, 0.033180, 0.033740, 0.033100, 0.032178,
    0.033049, 0.033637, 0.032264, 0.034223, 0.032436, 0.032217, 0.033785, 0.032365,
    0.031783, 0.033008, 0.032948, 0.031599, 0.032307, 0.031490, 0.031721, 0.031994,
    0.031745, 0.031604, 0.031248, 0.032420, 0.032007, 0.031366, 0.031033, 0.031104,
    0.031699, 0.031015, 0.030814, 0.031001, 0.030343, 0.030952, 0.030527, 0.030083,
    0.031091, 0.030860, 0.030448, 0.030978, 0.030526, 0.031969, 0.030986, 0.030985,
    0.030647, 0.030760, 0.031990
]
# Generate iterations corresponding to the values (assuming 10000 iterations per value)
iterations = np.arange(10000, 510000+10000, 10000)

# Plot MinMatDis - CD
plt.figure(figsize=(10, 5))
plt.plot(iterations, minmatdis_cd_values, marker='o', label='MinMatDis (CD)')
plt.xlabel('Iterations')
plt.ylabel('MinMatDis (CD)')
plt.title('Validation MinMatDis Chamfer Distance Curve')
plt.legend()
plt.grid(True)
plt.savefig('Validation_MinMatDis_CD_curve_corrected.png' , dpi=500)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# MinMatDis CD values from the provided file
minmatdis_cd_values = [
    0.037892, 0.035176, 0.034948, 0.034152, 0.033180, 0.033740, 0.033100, 0.032178,
    0.033049, 0.033637, 0.032264, 0.034223, 0.032436, 0.032217, 0.033785, 0.032365,
    0.031783, 0.033008, 0.032948, 0.031599, 0.032307, 0.031490, 0.031721, 0.031994,
    0.031745, 0.031604, 0.031248, 0.032420, 0.032007, 0.031366, 0.031033, 0.031104,
    0.031699, 0.031015, 0.030814, 0.031001, 0.030343, 0.030952, 0.030527, 0.030083,
    0.031091, 0.030860, 0.030448, 0.030978, 0.030526, 0.031969, 0.030986, 0.030985,
    0.030647, 0.030760, 0.031990
]

# Generate iterations corresponding to the values (assuming 10000 iterations per value)
iterations = np.arange(10000, 510000+10000, 10000)

# Plot MinMatDis - CD with log scale for x-axis
plt.figure(figsize=(10, 5))
plt.plot(iterations, minmatdis_cd_values, marker='o', label='MinMatDis (CD)')
plt.xscale('log')
plt.xlabel('Iterations (log scale)')
plt.ylabel('MinMatDis (CD)')
plt.title('Validation MinMatDis Chamfer Distance Curve')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.savefig('Validation_MinMatDis_CD_curve_corrected_log.png', dpi=500)
plt.show()

# %% [markdown]
# ### Plotting 1NN-Accuracy over iterations

# %%
# 1NN-Accur CD values from the provided file
nn_accur_cd_values = [
    0.841250, 0.808750, 0.793750, 0.788750, 0.778750, 0.787500, 0.777500,
    0.758750, 0.765000, 0.760000, 0.737500, 0.753750, 0.761250, 0.731250,
    0.760000, 0.736250, 0.736250, 0.743750, 0.750000, 0.747500, 0.746250,
    0.700000, 0.726250, 0.727500, 0.725000, 0.732500, 0.715000, 0.702500,
    0.725000, 0.711250, 0.697500, 0.715000, 0.706250, 0.690000, 0.716250,
    0.717500, 0.720000, 0.683750, 0.706250, 0.686250, 0.710000, 0.700000,
    0.700000, 0.691250, 0.681250, 0.691250, 0.711250, 0.691250, 0.705000,
    0.691250, 0.698750
]

# Generate iterations corresponding to the values (assuming 10000 iterations per value)
iterations = np.arange(10000, 510000+10000, 10000)

# Plot 1NN-Accur - CD
plt.figure(figsize=(10, 5))
plt.plot(iterations, nn_accur_cd_values, marker='o', label='1NN-Accur (CD)')
plt.xlabel('Iterations')
plt.ylabel('1NN-Accur (CD)')
plt.title('Validation 1NN-Accur Chamfer Distance Curve')
plt.legend()
plt.grid(True)
plt.savefig('Validation_1NN_Accur_CD_curve_corrected.png', dpi=500)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1NN-Accur CD values from the provided file
nn_accur_cd_values = [
    0.841250, 0.808750, 0.793750, 0.788750, 0.778750, 0.787500, 0.777500,
    0.758750, 0.765000, 0.760000, 0.737500, 0.753750, 0.761250, 0.731250,
    0.760000, 0.736250, 0.736250, 0.743750, 0.750000, 0.747500, 0.746250,
    0.700000, 0.726250, 0.727500, 0.725000, 0.732500, 0.715000, 0.702500,
    0.725000, 0.711250, 0.697500, 0.715000, 0.706250, 0.690000, 0.716250,
    0.717500, 0.720000, 0.683750, 0.706250, 0.686250, 0.710000, 0.700000,
    0.700000, 0.691250, 0.681250, 0.691250, 0.711250, 0.691250, 0.705000,
    0.691250, 0.698750
]

# Generate iterations corresponding to the values (assuming 10000 iterations per value)
iterations = np.arange(10000, 510000+10000, 10000)

# Plot 1NN-Accur - CD with log scale for x-axis
plt.figure(figsize=(10, 5))
plt.plot(iterations, nn_accur_cd_values, marker='o', label='1NN-Accur (CD)')
plt.xscale('log')
plt.xlabel('Iterations (log scale)')
plt.ylabel('1NN-Accur (CD)')
plt.title('Validation 1NN-Accur Chamfer Distance Curve')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.savefig('Validation_1NN_Accur_CD_curve_corrected_log.png', dpi=500)
plt.show()

# %% [markdown]
# ### Jensen-Shannon Divergence (JSD) over iterations

# %%
import numpy as np
import matplotlib.pyplot as plt

# Jensen-Shannon Divergence values from the provided file
jsd_values = [
    0.011660, 0.010308, 0.008783, 0.010315, 0.009275, 0.007963, 0.007624,
    0.006423, 0.007317, 0.008034, 0.007079, 0.009092, 0.008685, 0.007081,
    0.008068, 0.007402, 0.007187, 0.006623, 0.007263, 0.010559, 0.008663,
    0.007813, 0.007048, 0.008522, 0.007589, 0.006616, 0.007853, 0.007026,
    0.007574, 0.007993, 0.006876, 0.006544, 0.006739, 0.006694, 0.006692,
    0.006865, 0.006520, 0.006617, 0.006313, 0.007267, 0.006599, 0.006527,
    0.006347, 0.006910, 0.006283, 0.006751, 0.006112, 0.005817, 0.006093,
    0.006825, 0.006130
]

# Generate iterations corresponding to the values (assuming 10000 iterations per value)
iterations = np.arange(10000, 510000+10000, 10000)

# Plot Jensen-Shannon Divergence without log scale for x-axis
plt.figure(figsize=(10, 5))
plt.plot(iterations, jsd_values, marker='o', label='Jensen-Shannon Divergence')
plt.xlabel('Iterations')
plt.ylabel('Jensen-Shannon Divergence')
plt.title('Validation Jensen-Shannon Divergence Curve')
plt.legend()
plt.grid(True)
plt.savefig('Validation_JSD_curve_corrected.png', dpi=500)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Jensen-Shannon Divergence values from the provided file
jsd_values = [
    0.011660, 0.010308, 0.008783, 0.010315, 0.009275, 0.007963, 0.007624,
    0.006423, 0.007317, 0.008034, 0.007079, 0.009092, 0.008685, 0.007081,
    0.008068, 0.007402, 0.007187, 0.006623, 0.007263, 0.010559, 0.008663,
    0.007813, 0.007048, 0.008522, 0.007589, 0.006616, 0.007853, 0.007026,
    0.007574, 0.007993, 0.006876, 0.006544, 0.006739, 0.006694, 0.006692,
    0.006865, 0.006520, 0.006617, 0.006313, 0.007267, 0.006599, 0.006527,
    0.006347, 0.006910, 0.006283, 0.006751, 0.006112, 0.005817, 0.006093,
    0.006825, 0.006130
]

# Generate iterations corresponding to the values (assuming 10000 iterations per value)
iterations = np.arange(10000, 510000+10000, 10000)

# Plot Jensen-Shannon Divergence with log scale for x-axis
plt.figure(figsize=(10, 5))
plt.plot(iterations, jsd_values, marker='o', label='Jensen-Shannon Divergence')
plt.xscale('log')
plt.xlabel('Iterations (log scale)')
plt.ylabel('Jensen-Shannon Divergence')
plt.title('Validation Jensen-Shannon Divergence Curve')
plt.legend()
plt.grid(True, which="both", ls="--")
plt.savefig('Validation_JSD_curve_corrected_log.png', dpi=500)
plt.show()

# %% [markdown]
# ### Combined Validation Curves normal scale

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the plots
coverage_cd_values = [
    0.375000, 0.400000, 0.390000, 0.390000, 0.397500, 0.417500, 0.427500,
    0.417500, 0.400000, 0.395000, 0.410000, 0.410000, 0.422500, 0.412500,
    0.430000, 0.440000, 0.420000, 0.415000, 0.417500, 0.415000, 0.417500,
    0.407500, 0.445000, 0.422500, 0.417500, 0.435000, 0.415000, 0.412500,
    0.395000, 0.427500, 0.402500, 0.412500, 0.467500, 0.445000, 0.430000,
    0.410000, 0.425000, 0.437500, 0.437500, 0.407500, 0.405000, 0.410000,
    0.410000, 0.422500, 0.432500, 0.387500, 0.425000, 0.417500, 0.445000,
    0.430000, 0.417500
]

minmatdis_cd_values = [
    0.037892, 0.035176, 0.034948, 0.034152, 0.033180, 0.033740, 0.033100, 0.032178,
    0.033049, 0.033637, 0.032264, 0.034223, 0.032436, 0.032217, 0.033785, 0.032365,
    0.031783, 0.033008, 0.032948, 0.031599, 0.032307, 0.031490, 0.031721, 0.031994,
    0.031745, 0.031604, 0.031248, 0.032420, 0.032007, 0.031366, 0.031033, 0.031104,
    0.031699, 0.031015, 0.030814, 0.031001, 0.030343, 0.030952, 0.030527, 0.030083,
    0.031091, 0.030860, 0.030448, 0.030978, 0.030526, 0.031969, 0.030986, 0.030985,
    0.030647, 0.030760, 0.031990
]

nn_accur_cd_values = [
    0.841250, 0.808750, 0.793750, 0.788750, 0.778750, 0.787500, 0.777500,
    0.758750, 0.765000, 0.760000, 0.737500, 0.753750, 0.761250, 0.731250,
    0.760000, 0.736250, 0.736250, 0.743750, 0.750000, 0.747500, 0.746250,
    0.700000, 0.726250, 0.727500, 0.725000, 0.732500, 0.715000, 0.702500,
    0.725000, 0.711250, 0.697500, 0.715000, 0.706250, 0.690000, 0.716250,
    0.717500, 0.720000, 0.683750, 0.706250, 0.686250, 0.710000, 0.700000,
    0.700000, 0.691250, 0.681250, 0.691250, 0.711250, 0.691250, 0.705000,
    0.691250, 0.698750
]

jsd_values = [
    0.011660, 0.010308, 0.008783, 0.010315, 0.009275, 0.007963, 0.007624,
    0.006423, 0.007317, 0.008034, 0.007079, 0.009092, 0.008685, 0.007081,
    0.008068, 0.007402, 0.007187, 0.006623, 0.007263, 0.010559, 0.008663,
    0.007813, 0.007048, 0.008522, 0.007589, 0.006616, 0.007853, 0.007026,
    0.007574, 0.007993, 0.006876, 0.006544, 0.006739, 0.006694, 0.006692,
    0.006865, 0.006520, 0.006617, 0.006313, 0.007267, 0.006599, 0.006527,
    0.006347, 0.006910, 0.006283, 0.006751, 0.006112, 0.005817, 0.006093,
    0.006825, 0.006130
]

# Generate iterations corresponding to the values (assuming 10000 iterations per value)
iterations = np.arange(10000, 510000+10000, 10000)

# Plotting the combined figure with subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Coverage Chamfer Distance
axs[0, 0].plot(iterations, coverage_cd_values, label='Coverage Chamfer Distance (CD)', marker='o')
axs[0, 0].set_xlabel('Iterations')
axs[0, 0].set_ylabel('Coverage Chamfer Distance (CD)')
axs[0, 0].set_title('Coverage Chamfer Distance')
axs[0, 0].legend()
axs[0, 0].grid(True)

# MinMatDis Chamfer Distance
axs[0, 1].plot(iterations, minmatdis_cd_values, label='MinMatDis Chamfer Distance (CD)', marker='o')
axs[0, 1].set_xlabel('Iterations')
axs[0, 1].set_ylabel('MinMatDis Chamfer Distance (CD)')
axs[0, 1].set_title('MinMatDis Chamfer Distance')
axs[0, 1].legend()
axs[0, 1].grid(True)

# 1NN-Accur Chamfer Distance
axs[1, 0].plot(iterations, nn_accur_cd_values, label='1NN-Accur Chamfer Distance (CD)', marker='o')
axs[1, 0].set_xlabel('Iterations')
axs[1, 0].set_ylabel('1NN-Accur Chamfer Distance (CD)')
axs[1, 0].set_title('1NN-Accur Chamfer Distance')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Jensen-Shannon Divergence
axs[1, 1].plot(iterations, jsd_values, label='Jensen-Shannon Divergence', marker='o')
axs[1, 1].set_xlabel('Iterations')
axs[1, 1].set_ylabel('Jensen-Shannon Divergence')
axs[1, 1].set_title('Jensen-Shannon Divergence')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.savefig('Combined_Validation_Curves_Corrected.png', dpi=500)
plt.show()

# %% [markdown]
# ### Combined Validation Curves log scale

# %% [markdown]
# ### Combined Validation Curves single plot normal scale

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for the plots
coverage_cd_values = [
    0.375000, 0.400000, 0.390000, 0.390000, 0.397500, 0.417500, 0.427500,
    0.417500, 0.400000, 0.395000, 0.410000, 0.410000, 0.422500, 0.412500,
    0.430000, 0.440000, 0.420000, 0.415000, 0.417500, 0.415000, 0.417500,
    0.407500, 0.445000, 0.422500, 0.417500, 0.435000, 0.415000, 0.412500,
    0.395000, 0.427500, 0.402500, 0.412500, 0.467500, 0.445000, 0.430000,
    0.410000, 0.425000, 0.437500, 0.437500, 0.407500, 0.405000, 0.410000,
    0.410000, 0.422500, 0.432500, 0.387500, 0.425000, 0.417500, 0.445000,
    0.430000, 0.417500
]

minmatdis_cd_values = [
    0.037892, 0.035176, 0.034948, 0.034152, 0.033180, 0.033740, 0.033100, 0.032178,
    0.033049, 0.033637, 0.032264, 0.034223, 0.032436, 0.032217, 0.033785, 0.032365,
    0.031783, 0.033008, 0.032948, 0.031599, 0.032307, 0.031490, 0.031721, 0.031994,
    0.031745, 0.031604, 0.031248, 0.032420, 0.032007, 0.031366, 0.031033, 0.031104,
    0.031699, 0.031015, 0.030814, 0.031001, 0.030343, 0.030952, 0.030527, 0.030083,
    0.031091, 0.030860, 0.030448, 0.030978, 0.030526, 0.031969, 0.030986, 0.030985,
    0.030647, 0.030760, 0.031990
]

nn_accur_cd_values = [
    0.841250, 0.808750, 0.793750, 0.788750, 0.778750, 0.787500, 0.777500,
    0.758750, 0.765000, 0.760000, 0.737500, 0.753750, 0.761250, 0.731250,
    0.760000, 0.736250, 0.736250, 0.743750, 0.750000, 0.747500, 0.746250,
    0.700000, 0.726250, 0.727500, 0.725000, 0.732500, 0.715000, 0.702500,
    0.725000, 0.711250, 0.697500, 0.715000, 0.706250, 0.690000, 0.716250,
    0.717500, 0.720000, 0.683750, 0.706250, 0.686250, 0.710000, 0.700000,
    0.700000, 0.691250, 0.681250, 0.691250, 0.711250, 0.691250, 0.705000,
    0.691250, 0.698750
]

jsd_values = [
    0.011660, 0.010308, 0.008783, 0.010315, 0.009275, 0.007963, 0.007624,
    0.006423, 0.007317, 0.008034, 0.007079, 0.009092, 0.008685, 0.007081,
    0.008068, 0.007402, 0.007187, 0.006623, 0.007263, 0.010559, 0.008663,
    0.007813, 0.007048, 0.008522, 0.007589, 0.006616, 0.007853, 0.007026,
    0.007574, 0.007993, 0.006876, 0.006544, 0.006739, 0.006694, 0.006692,
    0.006865, 0.006520, 0.006617, 0.006313, 0.007267, 0.006599, 0.006527,
    0.006347, 0.006910, 0.006283, 0.006751, 0.006112, 0.005817, 0.006093,
    0.006825, 0.006130
]

# Generate iterations corresponding to the values (assuming 10000 iterations per value)
iterations = np.arange(10000, 510000+10000, 10000)

# Plotting all four metrics in one plot
plt.figure(figsize=(15, 10))

# Plot each metric
plt.plot(iterations, coverage_cd_values, marker='o', label='Coverage Chamfer Distance (CD)')
plt.plot(iterations, minmatdis_cd_values, marker='s', label='MinMatDis Chamfer Distance (CD)')
plt.plot(iterations, nn_accur_cd_values, marker='^', label='1NN-Accur Chamfer Distance (CD)')
plt.plot(iterations, jsd_values, marker='x', label='Jensen-Shannon Divergence')

# Labels and title
plt.xlabel('Iterations')
plt.ylabel('Values')
plt.title('Validation Metrics Over Iterations')
plt.legend()
plt.grid(True)

# Save and show the plot
plt.savefig('Combined_Validation_Metrics.png', dpi=500)
plt.show()

# %% [markdown]
# ### Combined Validation Curves single plot log scale
