# %% [markdown]
# ### Importing training file

# %% [markdown]
# ### Plotting Coverage over iterations

# %%
import matplotlib.pyplot as plt

# File path
file_path = 'Converage_150_1040k.txt'

# Read the file content
with open(file_path, 'r', encoding="utf-8") as f:
    lines = f.readlines()

# Extract CD values from each line
cd_values = [float(line.strip().split()[-1]) for line in lines]

# Generate iterations (starting from 10000, 20000, ..., etc.)
iterations = [(i + 1) * 10000 for i in range(len(cd_values))]

# Plotting the validation curve for Chamfer Distance (CD)
plt.figure(figsize=(10, 5))
plt.plot(iterations, cd_values, label='Chamfer Distance (CD)', marker='o')
plt.xlabel('Iterations')
plt.ylabel('Coverage (CD)')
plt.title('Validation Coverage Chamfer Distance Curve Configuration 2')
plt.legend()
plt.grid(True)
plt.savefig('Validation_CD_curve.png', dpi=500)
plt.show()

# %% [markdown]
# ### Plotting MinMatDis over iterations

# %%
import matplotlib.pyplot as plt

# File path for MinMatDis values
file_path = 'MinMatDis_150_1040k.txt'

# Read the file content
with open(file_path, 'r', encoding="utf-8") as f:
    lines = f.readlines()

# Extract CD values from each line
cd_values = [float(line.strip().split()[-1]) for line in lines]

# Generate iterations (starting from 10000, 20000, ..., etc.)
iterations = [(i + 1) * 10000 for i in range(len(cd_values))]

# Plotting the validation curve for Chamfer Distance (CD) with log scale on x-axis
plt.figure(figsize=(10, 5))
plt.plot(iterations, cd_values, label='MinMatDis Chamfer Distance (CD)', marker='o')
plt.xlabel('Iterations (log scale)')
plt.ylabel('MinMatDis (CD)')
plt.xscale('log')
plt.title('Validation MinMatDis Chamfer Distance Curve Configuration 2')
plt.legend()
plt.grid(True)
plt.savefig('Validation_MinMatDis_CD_curve_log_scale.png', dpi=500)
plt.show()

# %%
# Plotting the validation curve for Chamfer Distance (CD) with normal scale on x-axis
plt.figure(figsize=(10, 5))
plt.plot(iterations, cd_values, label='MinMatDis Chamfer Distance (CD)', marker='o')
plt.xlabel('Iterations')
plt.ylabel('MinMatDis (CD)')
plt.title('Validation MinMatDis Chamfer Distance Curve Configuration 2')
plt.legend()
plt.grid(True)
plt.savefig('Validation_MinMatDis_CD_curve.png', dpi=500)
plt.show()

# %% [markdown]
# ### Plotting 1NN-Accuracy over iterations

# %%
import matplotlib.pyplot as plt

# File path for 1NN-Accur values
file_path = '1NN_150_1040k.txt'

# Read the file content
with open(file_path, 'r', encoding="utf-8") as f:
    lines = f.readlines()

# Extract CD values from each line
cd_values = [float(line.strip().split()[-1]) for line in lines]

# Generate iterations (starting from 10000, 20000, ..., etc.)
iterations = [(i + 1) * 10000 for i in range(len(cd_values))]

# Plotting the validation curve for 1NN-Accur with log scale on x-axis
plt.figure(figsize=(10, 5))
plt.plot(iterations, cd_values, label='1NN-Accur Chamfer Distance (CD)', marker='o')
plt.xlabel('Iterations (log scale)')
plt.ylabel('1NN-Accur (CD)')
plt.xscale('log')
plt.title('Validation 1NN-Accur Chamfer Distance Curve Configuration 2')
plt.legend()
plt.grid(True)
plt.savefig('Validation_1NN_Accur_CD_curve_log_scale.png', dpi=500)
plt.show()

# %%
# Plotting the validation curve for 1NN-Accur with normal scale on x-axis
plt.figure(figsize=(10, 5))
plt.plot(iterations, cd_values, label='1NN-Accur Chamfer Distance (CD)', marker='o')
plt.xlabel('Iterations')
plt.ylabel('1NN-Accur (CD)')
plt.title('Validation 1NN-Accur Chamfer Distance Curve Configuration 2')
plt.legend()
plt.grid(True)
plt.savefig('Validation_1NN_Accur_CD_curve.png', dpi=500)
plt.show()

# %% [markdown]
# ### Jensen-Shannon Divergence (JSD) over iterations

# %%
import matplotlib.pyplot as plt

# File path for Jensen-Shannon Divergence values
file_path = 'JSD_150_1040k.txt'

# Read the file content
with open(file_path, 'r', encoding="utf-8") as f:
    lines = f.readlines()

# Extract Jensen-Shannon Divergence values from each line
jsnshndis_values = [float(line.strip().split()[-1]) for line in lines]

# Generate iterations (starting from 10000, 20000, ..., etc.)
iterations = [(i + 1) * 10000 for i in range(len(jsnshndis_values))]

# Plotting the validation curve for Jensen-Shannon Divergence with log scale on x-axis
plt.figure(figsize=(10, 5))
plt.plot(iterations, jsnshndis_values, label='Jensen-Shannon Divergence', marker='o')
plt.xlabel('Iterations (log scale)')
plt.ylabel('Jensen-Shannon Divergence')
plt.xscale('log')
plt.title('Validation Jensen-Shannon Divergence Curve (Log Scale)')
plt.legend()
plt.grid(True)
plt.savefig('Validation_Jensen_Shannon_Divergence_curve_log_scale.png', dpi=500)
plt.show()

# %%
# Plotting the validation curve for Jensen-Shannon Divergence with normal scale on x-axis
plt.figure(figsize=(10, 5))
plt.plot(iterations, jsnshndis_values, label='Jensen-Shannon Divergence', marker='o')
plt.xlabel('Iterations')
plt.ylabel('Jensen-Shannon Divergence')
plt.title('Validation Jensen-Shannon Divergence Curve Configuration 2')
plt.legend()
plt.grid(True)
plt.savefig('Validation_Jensen_Shannon_Divergence_curve.png', dpi=500)
plt.show()

# %% [markdown]
# ### Combined Validation Curves normal scale

# %%
import matplotlib.pyplot as plt

# File paths
file_paths = {
    'Coverage': 'Converage_150_1040k.txt',
    'MinMatDis': 'MinMatDis_150_1040k.txt',
    '1NN-Accur': '1NN_150_1040k.txt',
    'Jensen-Shannon': 'JSD_150_1040k.txt'
}

# Read the file contents
data = {}
for key, file_path in file_paths.items():
    with open(file_path, 'r', encoding="utf-8") as f:
        lines = f.readlines()
        values = [float(line.strip().split()[-1]) for line in lines]
        data[key] = values

# Generate iterations (starting from 10000, 20000, ..., etc.)
iterations = [(i + 1) * 10000 for i in range(len(data['Coverage']))]

# Plotting the combined figure with subplots
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Coverage Chamfer Distance (Normal Scale)
axs[0, 0].plot(iterations, data['Coverage'], label='Coverage Chamfer Distance (CD)', marker='o')
axs[0, 0].set_xlabel('Iterations')
axs[0, 0].set_ylabel('Coverage Chamfer Distance (CD)')
axs[0, 0].set_title('Coverage Chamfer Distance Configuration 2')
axs[0, 0].legend()
axs[0, 0].grid(True)

# MinMatDis Chamfer Distance (Normal Scale)
axs[0, 1].plot(iterations, data['MinMatDis'], label='MinMatDis Chamfer Distance (CD)', marker='o')
axs[0, 1].set_xlabel('Iterations')
axs[0, 1].set_ylabel('MinMatDis Chamfer Distance (CD)')
axs[0, 1].set_title('MinMatDis Chamfer Distance Configuration 2')
axs[0, 1].legend()
axs[0, 1].grid(True)

# 1NN-Accur Chamfer Distance (Normal Scale)
axs[1, 0].plot(iterations, data['1NN-Accur'], label='1NN-Accur Chamfer Distance (CD)', marker='o')
axs[1, 0].set_xlabel('Iterations')
axs[1, 0].set_ylabel('1NN-Accur Chamfer Distance (CD)')
axs[1, 0].set_title('1NN-Accur Chamfer Distance Configuration 2')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Jensen-Shannon Divergence (Normal Scale)
axs[1, 1].plot(iterations, data['Jensen-Shannon'], label='Jensen-Shannon Divergence', marker='o')
axs[1, 1].set_xlabel('Iterations')
axs[1, 1].set_ylabel('Jensen-Shannon Divergence')
axs[1, 1].set_title('Jensen-Shannon Divergence Configuration 2')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.savefig('Combined_Validation_Curves_configuration_2_1040k.png', dpi=500)
plt.show()

# %% [markdown]
# ### Combined Validation Curves log scale

# %%
import matplotlib.pyplot as plt

# File paths
file_paths = {
    'Coverage': 'Converage_150_1040k.txt',
    'MinMatDis': 'MinMatDis_150_1040k.txt',
    '1NN-Accur': '1NN_150_1040k.txt',
    'Jensen-Shannon': 'JSD_150_1040k.txt'
}

# Read the file contents
data = {}
for key, file_path in file_paths.items():
    with open(file_path, 'r', encoding="utf-8") as f:
        lines = f.readlines()
        values = [float(line.strip().split()[-1]) for line in lines]
        data[key] = values

# Generate iterations (starting from 10000, 20000, ..., etc.)
iterations = [(i + 1) * 10000 for i in range(len(data['Coverage']))]

# Plotting the combined figure with subplots in log format
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Coverage Chamfer Distance (Log Scale)
axs[0, 0].plot(iterations, data['Coverage'], label='Coverage Chamfer Distance (CD)', marker='o')
axs[0, 0].set_xlabel('Iterations (log scale)')
axs[0, 0].set_ylabel('Chamfer Distance (CD)')
axs[0, 0].set_xscale('log')
axs[0, 0].set_title('Coverage Chamfer Distance (Log Scale)')
axs[0, 0].legend()
axs[0, 0].grid(True)

# MinMatDis Chamfer Distance (Log Scale)
axs[0, 1].plot(iterations, data['MinMatDis'], label='MinMatDis Chamfer Distance (CD)', marker='o')
axs[0, 1].set_xlabel('Iterations (log scale)')
axs[0, 1].set_ylabel('Chamfer Distance (CD)')
axs[0, 1].set_xscale('log')
axs[0, 1].set_title('MinMatDis Chamfer Distance (Log Scale)')
axs[0, 1].legend()
axs[0, 1].grid(True)

# 1NN-Accur Chamfer Distance (Log Scale)
axs[1, 0].plot(iterations, data['1NN-Accur'], label='1NN-Accur Chamfer Distance (CD)', marker='o')
axs[1, 0].set_xlabel('Iterations (log scale)')
axs[1, 0].set_ylabel('Chamfer Distance (CD)')
axs[1, 0].set_xscale('log')
axs[1, 0].set_title('1NN-Accur Chamfer Distance (Log Scale)')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Jensen-Shannon Divergence (Log Scale)
axs[1, 1].plot(iterations, data['Jensen-Shannon'], label='Jensen-Shannon Divergence', marker='o')
axs[1, 1].set_xlabel('Iterations (log scale)')
axs[1, 1].set_ylabel('Jensen-Shannon Divergence')
axs[1, 1].set_xscale('log')
axs[1, 1].set_title('Jensen-Shannon Divergence (Log Scale)')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.savefig('Combined_Validation_Curves_Log.png', dpi=500)
plt.show()

# %% [markdown]
# ### Combined Validation Curves single plot normal scale

# %%
import matplotlib.pyplot as plt

# File paths
file_paths = {
    'Coverage': 'Converage_150_1040k.txt',
    'MinMatDis': 'MinMatDis_150_1040k.txt',
    '1NN-Accur': '1NN_150_1040k.txt',
    'Jensen-Shannon': 'JSD_150_1040k.txt'
}

# Read the file contents
data = {}
for key, file_path in file_paths.items():
    with open(file_path, 'r', encoding="utf-8") as f:
        lines = f.readlines()
        values = [float(line.strip().split()[-1]) for line in lines]
        data[key] = values

# Generate iterations (starting from 10000, 20000, ..., etc.)
iterations = [(i + 1) * 10000 for i in range(len(data['Coverage']))]

# Plotting the combined figure with all metrics in non-log format
plt.figure(figsize=(15, 10))

# Plot each metric with a unique color and label
plt.plot(iterations, data['Coverage'], label='Coverage Chamfer Distance (CD)', marker='o', color='b')
plt.plot(iterations, data['MinMatDis'], label='MinMatDis Chamfer Distance (CD)', marker='x', color='g')
plt.plot(iterations, data['1NN-Accur'], label='1NN-Accur Chamfer Distance (CD)', marker='s', color='r')
plt.plot(iterations, data['Jensen-Shannon'], label='Jensen-Shannon Divergence', marker='d', color='m')

# Adding titles and labels
plt.xlabel('Iterations')
plt.ylabel('Values')
plt.title('Combined Validation Curves')
plt.legend()
plt.grid(True)
plt.savefig('Combined_Validation_Curves_Single_Plot.png', dpi=500)
plt.show()

# %% [markdown]
# ### Combined Validation Curves single plot log scale

# %%
import matplotlib.pyplot as plt

# File paths
file_paths = {
    'Coverage': 'Converage_150_1040k.txt',
    'MinMatDis': 'MinMatDis_150_1040k.txt',
    '1NN-Accur': '1NN_150_1040k.txt',
    'Jensen-Shannon': 'JSD_150_1040k.txt'
}

# Read the file contents
data = {}
for key, file_path in file_paths.items():
    with open(file_path, 'r', encoding="utf-8") as f:
        lines = f.readlines()
        values = [float(line.strip().split()[-1]) for line in lines]
        data[key] = values

# Generate iterations (starting from 10000, 20000, ..., etc.)
iterations = [(i + 1) * 10000 for i in range(len(data['Coverage']))]

# Plotting the combined figure with all metrics in log format
plt.figure(figsize=(15, 10))

# Plot each metric with a unique color and label
plt.plot(iterations, data['Coverage'], label='Coverage Chamfer Distance (CD)', marker='o', color='b')
plt.plot(iterations, data['MinMatDis'], label='MinMatDis Chamfer Distance (CD)', marker='x', color='g')
plt.plot(iterations, data['1NN-Accur'], label='1NN-Accur Chamfer Distance (CD)', marker='s', color='r')
plt.plot(iterations, data['Jensen-Shannon'], label='Jensen-Shannon Divergence', marker='d', color='m')

# Adding titles and labels
plt.xlabel('Iterations (log scale)')
plt.ylabel('Values')
plt.xscale('log')
plt.title('Combined Validation Curves (Log Scale)')
plt.legend()
plt.grid(True)
plt.savefig('Combined_Validation_Curves_Single_Plot_Log.png', dpi=500)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for Baseline Model
baseline_coverage_cd_values = [
    0.375000, 0.400000, 0.390000, 0.390000, 0.397500, 0.417500, 0.427500, 0.417500, 0.400000, 0.395000, 0.410000, 0.410000, 0.422500, 0.412500, 0.430000, 0.440000, 0.420000, 0.415000, 0.417500, 0.415000, 0.417500, 0.407500, 0.445000, 0.422500, 0.417500, 0.435000, 0.415000, 0.412500, 0.395000, 0.427500, 0.402500, 0.412500, 0.467500, 0.445000, 0.430000, 0.410000, 0.425000, 0.437500, 0.437500, 0.407500, 0.405000, 0.410000, 0.410000, 0.422500, 0.432500, 0.387500, 0.425000, 0.417500, 0.445000, 0.430000, 0.417500, 0.410000, 0.432500, 0.425000, 0.415000, 0.432500, 0.437500, 0.390000, 0.442500, 0.425000, 0.392500, 0.387500, 0.425000, 0.415000, 0.437500, 0.427500, 0.410000, 0.430000, 0.420000, 0.410000, 0.415000, 0.417500, 0.437500, 0.430000, 0.422500, 0.412500, 0.430000
]

baseline_minmatdis_cd_values = [
    0.037892, 0.035176, 0.034948, 0.034152, 0.033180, 0.033740, 0.033100, 0.032178, 0.033049, 0.033637, 0.032264, 0.034223, 0.032436, 0.032217, 0.033785, 0.032365, 0.031783, 0.033008, 0.032948, 0.031599, 0.032307, 0.031490, 0.031721, 0.031994, 0.031745, 0.031604, 0.031248, 0.032420, 0.032007, 0.031366, 0.031033, 0.031104, 0.031699, 0.031015, 0.030814, 0.031001, 0.030343, 0.030952, 0.030527, 0.030083, 0.031091, 0.030860, 0.030448, 0.030978, 0.030526, 0.031969, 0.030986, 0.030985, 0.030647, 0.030760, 0.031990, 0.030478, 0.031029, 0.030957, 0.031144, 0.030359, 0.029811, 0.030685, 0.029760, 0.030461, 0.031201, 0.030845, 0.031052, 0.031331, 0.030598, 0.031810, 0.031178, 0.031169, 0.030582, 0.030887, 0.030498, 0.030411, 0.030863, 0.030243, 0.030890, 0.031709, 0.030673
]

baseline_nn_accur_cd_values = [
    0.841250, 0.808750, 0.793750, 0.788750, 0.778750, 0.787500, 0.777500, 0.758750, 0.765000, 0.760000, 0.737500, 0.753750, 0.761250, 0.731250, 0.760000, 0.736250, 0.736250, 0.743750, 0.750000, 0.747500, 0.746250, 0.700000, 0.726250, 0.727500, 0.725000, 0.732500, 0.715000, 0.702500, 0.725000, 0.711250, 0.697500, 0.715000, 0.706250, 0.690000, 0.716250, 0.717500, 0.720000, 0.683750, 0.706250, 0.686250, 0.710000, 0.700000, 0.700000, 0.691250, 0.681250, 0.691250, 0.711250, 0.691250, 0.705000, 0.691250, 0.698750, 0.673750, 0.705000, 0.687500, 0.690000, 0.685000, 0.680000, 0.695000, 0.701250, 0.676250, 0.695000, 0.690000, 0.705000, 0.692500, 0.676250, 0.713750, 0.687500, 0.697500, 0.712500, 0.688750, 0.685000, 0.702500, 0.692500, 0.696250, 0.701250, 0.718750, 0.691250
]

baseline_jsd_values = [
    0.011660, 0.010308, 0.008783, 0.010315, 0.009275, 0.007963, 0.007624, 0.006423, 0.007317, 0.008034, 0.007079, 0.009092, 0.008685, 0.007081, 0.008068, 0.007402, 0.007187, 0.006623, 0.007263, 0.010559, 0.008663, 0.007813, 0.007048, 0.008522, 0.007589, 0.006616, 0.007853, 0.007026, 0.007574, 0.007993, 0.006876, 0.006544, 0.006739, 0.006694, 0.006692, 0.006865, 0.006520, 0.006617, 0.006313, 0.007267, 0.006599, 0.006527, 0.006347, 0.006910, 0.006283, 0.006751, 0.006112, 0.005817, 0.006093, 0.006825, 0.006130, 0.006321, 0.006961, 0.006951, 0.007641, 0.006840, 0.006043, 0.006177, 0.006360, 0.006466, 0.007337, 0.006241, 0.007275, 0.006531, 0.006285, 0.007482, 0.006232, 0.007063, 0.006424, 0.007014, 0.006679, 0.006590, 0.006497, 0.006257, 0.007367, 0.007133, 0.006613
]

# Generate iterations corresponding to the values (assuming 10000 iterations per value)
baseline_iterations = np.arange(10000, 770000+10000, 10000)

# Data for Configuration 1
file_paths_config1 = {
    'Coverage': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_250\1040k iterations\Coverage_250_1040k.txt',
    'MinMatDis': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_250\1040k iterations\MinMatDis_250_1040k.txt',
    '1NN-Accur': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_250\1040k iterations\1NN-Accur_250_1040k.txt',
    'Jensen-Shannon': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_250\1040k iterations\JensensShnDis_250_1040k.txt'
}

# Read the file contents for Configuration 1
config1_data = {}
for key, file_path in file_paths_config1.items():
    with open(file_path, 'r', encoding="utf-8") as f:
        lines = f.readlines()
        values = [float(line.strip().split()[-1]) for line in lines]
        config1_data[key] = values

# Generate iterations for Configuration 1 (assuming 10000 iterations per value)
config1_iterations = [(i + 1) * 10000 for i in range(len(config1_data['Coverage']))]

# Data for Configuration 2
file_paths_config2 = {
    'Coverage': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_150\1040k iterations\Converage_150_1040k.txt',
    'MinMatDis': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_150\1040k iterations\MinMatDis_150_1040k.txt',
    '1NN-Accur': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_150\1040k iterations\1NN_150_1040k.txt',
    'Jensen-Shannon': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_150\1040k iterations\JSD_150_1040k.txt'
}

# Read the file contents for Configuration 2
config2_data = {}
for key, file_path in file_paths_config2.items():
    with open(file_path, 'r', encoding="utf-8") as f:
        lines = f.readlines()
        values = [float(line.strip().split()[-1]) for line in lines]
        config2_data[key] = values

# Generate iterations for Configuration 2 (assuming 10000 iterations per value)
config2_iterations = [(i + 1) * 10000 for i in range(len(config2_data['Coverage']))]

# Plotting the combined figure
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Coverage Chamfer Distance
axs[0, 0].plot(baseline_iterations, baseline_coverage_cd_values, label='Baseline - Coverage CD', color='blue', marker='o')
axs[0, 0].plot(config1_iterations, config1_data['Coverage'], label='Configuration 1 - Coverage CD', color='red', marker='x')
axs[0, 0].plot(config2_iterations, config2_data['Coverage'], label='Configuration 2 - Coverage CD', color='green', marker='s')
axs[0, 0].set_xlabel('Iterations')
axs[0, 0].set_ylabel('Coverage Chamfer Distance (CD)')
axs[0, 0].set_title('Coverage Chamfer Distance')
axs[0, 0].legend()
axs[0, 0].grid(True)

# MinMatDis Chamfer Distance
axs[0, 1].plot(baseline_iterations, baseline_minmatdis_cd_values, label='Baseline - MinMatDis CD', color='blue', marker='o')
axs[0, 1].plot(config1_iterations, config1_data['MinMatDis'], label='Configuration 1 - MinMatDis CD', color='red', marker='x')
axs[0, 1].plot(config2_iterations, config2_data['MinMatDis'], label='Configuration 2 - MinMatDis CD', color='green', marker='s')
axs[0, 1].set_xlabel('Iterations')
axs[0, 1].set_ylabel('MinMatDis Chamfer Distance (CD)')
axs[0, 1].set_title('MinMatDis Chamfer Distance')
axs[0, 1].legend()
axs[0, 1].grid(True)

# 1NN-Accur Chamfer Distance
axs[1, 0].plot(baseline_iterations, baseline_nn_accur_cd_values, label='Baseline - 1NN-Accur CD', color='blue', marker='o')
axs[1, 0].plot(config1_iterations, config1_data['1NN-Accur'], label='Configuration 1 - 1NN-Accur CD', color='red', marker='x')
axs[1, 0].plot(config2_iterations, config2_data['1NN-Accur'], label='Configuration 2 - 1NN-Accur CD', color='green', marker='s')
axs[1, 0].set_xlabel('Iterations')
axs[1, 0].set_ylabel('1NN-Accur Chamfer Distance (CD)')
axs[1, 0].set_title('1NN-Accur Chamfer Distance')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Jensen-Shannon Divergence
axs[1, 1].plot(baseline_iterations, baseline_jsd_values, label='Baseline - JSD', color='blue', marker='o')
axs[1, 1].plot(config1_iterations, config1_data['Jensen-Shannon'], label='Configuration 1 - JSD', color='red', marker='x')
axs[1, 1].plot(config2_iterations, config2_data['Jensen-Shannon'], label='Configuration 2 - JSD', color='green', marker='s')
axs[1, 1].set_xlabel('Iterations')
axs[1, 1].set_ylabel('Jensen-Shannon Divergence')
axs[1, 1].set_title('Jensen-Shannon Divergence')
axs[1, 1].legend()
axs[1, 1].grid(True)

# Add a note explaining the differences
fig.text(0.5, -0.1, 'Note: These plots represent validation metrics. The scale of Chamfer distance is different in the training script. '
                   'During the validation stage, a subset of the validation set (400 point clouds) is used, leading to potential differences in MMD scores.', 
         ha='center', wrap=True)

# Adjust layout
plt.tight_layout()
plt.savefig('Combined_Validation_Curves_Comparison_default_config_1_2.png', dpi=500)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for Baseline Model
baseline_coverage_cd_values = [
    0.375000, 0.400000, 0.390000, 0.390000, 0.397500, 0.417500, 0.427500, 0.417500, 0.400000, 0.395000, 0.410000, 0.410000, 0.422500, 0.412500, 0.430000, 0.440000, 0.420000, 0.415000, 0.417500, 0.415000, 0.417500, 0.407500, 0.445000, 0.422500, 0.417500, 0.435000, 0.415000, 0.412500, 0.395000, 0.427500, 0.402500, 0.412500, 0.467500, 0.445000, 0.430000, 0.410000, 0.425000, 0.437500, 0.437500, 0.407500, 0.405000, 0.410000, 0.410000, 0.422500, 0.432500, 0.387500, 0.425000, 0.417500, 0.445000, 0.430000, 0.417500, 0.410000, 0.432500, 0.425000, 0.415000, 0.432500, 0.437500, 0.390000, 0.442500, 0.425000, 0.392500, 0.387500, 0.425000, 0.415000, 0.437500, 0.427500, 0.410000, 0.430000, 0.420000, 0.410000, 0.415000, 0.417500, 0.437500, 0.430000, 0.422500, 0.412500, 0.430000
]

baseline_minmatdis_cd_values = [
    0.037892, 0.035176, 0.034948, 0.034152, 0.033180, 0.033740, 0.033100, 0.032178, 0.033049, 0.033637, 0.032264, 0.034223, 0.032436, 0.032217, 0.033785, 0.032365, 0.031783, 0.033008, 0.032948, 0.031599, 0.032307, 0.031490, 0.031721, 0.031994, 0.031745, 0.031604, 0.031248, 0.032420, 0.032007, 0.031366, 0.031033, 0.031104, 0.031699, 0.031015, 0.030814, 0.031001, 0.030343, 0.030952, 0.030527, 0.030083, 0.031091, 0.030860, 0.030448, 0.030978, 0.030526, 0.031969, 0.030986, 0.030985, 0.030647, 0.030760, 0.031990, 0.030478, 0.031029, 0.030957, 0.031144, 0.030359, 0.029811, 0.030685, 0.029760, 0.030461, 0.031201, 0.030845, 0.031052, 0.031331, 0.030598, 0.031810, 0.031178, 0.031169, 0.030582, 0.030887, 0.030498, 0.030411, 0.030863, 0.030243, 0.030890, 0.031709, 0.030673
]

baseline_nn_accur_cd_values = [
    0.841250, 0.808750, 0.793750, 0.788750, 0.778750, 0.787500, 0.777500, 0.758750, 0.765000, 0.760000, 0.737500, 0.753750, 0.761250, 0.731250, 0.760000, 0.736250, 0.736250, 0.743750, 0.750000, 0.747500, 0.746250, 0.700000, 0.726250, 0.727500, 0.725000, 0.732500, 0.715000, 0.702500, 0.725000, 0.711250, 0.697500, 0.715000, 0.706250, 0.690000, 0.716250, 0.717500, 0.720000, 0.683750, 0.706250, 0.686250, 0.710000, 0.700000, 0.700000, 0.691250, 0.681250, 0.691250, 0.711250, 0.691250, 0.705000, 0.691250, 0.698750, 0.673750, 0.705000, 0.687500, 0.690000, 0.685000, 0.680000, 0.695000, 0.701250, 0.676250, 0.695000, 0.690000, 0.705000, 0.692500, 0.676250, 0.713750, 0.687500, 0.697500, 0.712500, 0.688750, 0.685000, 0.702500, 0.692500, 0.696250, 0.701250, 0.718750, 0.691250
]

baseline_jsd_values = [
    0.011660, 0.010308, 0.008783, 0.010315, 0.009275, 0.007963, 0.007624, 0.006423, 0.007317, 0.008034, 0.007079, 0.009092, 0.008685, 0.007081, 0.008068, 0.007402, 0.007187, 0.006623, 0.007263, 0.010559, 0.008663, 0.007813, 0.007048, 0.008522, 0.007589, 0.006616, 0.007853, 0.007026, 0.007574, 0.007993, 0.006876, 0.006544, 0.006739, 0.006694, 0.006692, 0.006865, 0.006520, 0.006617, 0.006313, 0.007267, 0.006599, 0.006527, 0.006347, 0.006910, 0.006283, 0.006751, 0.006112, 0.005817, 0.006093, 0.006825, 0.006130, 0.006321, 0.006961, 0.006951, 0.007641, 0.006840, 0.006043, 0.006177, 0.006360, 0.006466, 0.007337, 0.006241, 0.007275, 0.006531, 0.006285, 0.007482, 0.006232, 0.007063, 0.006424, 0.007014, 0.006679, 0.006590, 0.006497, 0.006257, 0.007367, 0.007133, 0.006613
]

# Generate iterations corresponding to the values (assuming 10000 iterations per value)
baseline_iterations = np.arange(10000, 770000+10000, 10000)

# Data for Configuration 1
file_paths_config1 = {
    'Coverage': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_250\1040k iterations\Coverage_250_1040k.txt',
    'MinMatDis': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_250\1040k iterations\MinMatDis_250_1040k.txt',
    '1NN-Accur': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_250\1040k iterations\1NN-Accur_250_1040k.txt',
    'Jensen-Shannon': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_250\1040k iterations\JensensShnDis_250_1040k.txt'
}

# Read the file contents for Configuration 1
config1_data = {}
for key, file_path in file_paths_config1.items():
    with open(file_path, 'r', encoding="utf-8") as f:
        lines = f.readlines()
        values = [float(line.strip().split()[-1]) for line in lines]
        config1_data[key] = values

# Generate iterations for Configuration 1 (assuming 10000 iterations per value)
config1_iterations = [(i + 1) * 10000 for i in range(len(config1_data['Coverage']))]

# Data for Configuration 2
file_paths_config2 = {
    'Coverage': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_150\1040k iterations\Converage_150_1040k.txt',
    'MinMatDis': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_150\1040k iterations\MinMatDis_150_1040k.txt',
    '1NN-Accur': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_150\1040k iterations\1NN_150_1040k.txt',
    'Jensen-Shannon': r'C:\Users\henri\Documents\Git\Git_Projects\Classifier_Guided_Diffusion_for_Point_Clouds-1\Analysis\Generator\Configuration_150\1040k iterations\JSD_150_1040k.txt'
}

# Read the file contents for Configuration 2
config2_data = {}
for key, file_path in file_paths_config2.items():
    with open(file_path, 'r', encoding="utf-8") as f:
        lines = f.readlines()
        values = [float(line.strip().split()[-1]) for line in lines]
        config2_data[key] = values

# Generate iterations for Configuration 2 (assuming 10000 iterations per value)
config2_iterations = [(i + 1) * 10000 for i in range(len(config2_data['Coverage']))]

# Plotting the combined figure
fig, axs = plt.subplots(2, 2, figsize=(15, 10))

# Coverage Chamfer Distance
axs[0, 0].plot(baseline_iterations, baseline_coverage_cd_values, label='Baseline - Coverage CD', color='blue', marker='o', alpha=0.3)
axs[0, 0].plot(config1_iterations, config1_data['Coverage'], label='Configuration 1 - Coverage CD', color='red', marker='x', alpha=0.3)
axs[0, 0].plot(config2_iterations, config2_data['Coverage'], label='Configuration 2 - Coverage CD', color='green', marker='s')
axs[0, 0].set_xlabel('Iterations')
axs[0, 0].set_ylabel('Coverage Chamfer Distance (CD)')
axs[0, 0].set_title('Coverage Chamfer Distance')
axs[0, 0].legend()
axs[0, 0].grid(True)

# MinMatDis Chamfer Distance
axs[0, 1].plot(baseline_iterations, baseline_minmatdis_cd_values, label='Baseline - MinMatDis CD', color='blue', marker='o', alpha=0.3)
axs[0, 1].plot(config1_iterations, config1_data['MinMatDis'], label='Configuration 1 - MinMatDis CD', color='red', marker='x', alpha=0.3)
axs[0, 1].plot(config2_iterations, config2_data['MinMatDis'], label='Configuration 2 - MinMatDis CD', color='green', marker='s')
axs[0, 1].set_xlabel('Iterations')
axs[0, 1].set_ylabel('MinMatDis Chamfer Distance (CD)')
axs[0, 1].set_title('MinMatDis Chamfer Distance')
axs[0, 1].legend()
axs[0, 1].grid(True)

# 1NN-Accur Chamfer Distance
axs[1, 0].plot(baseline_iterations, baseline_nn_accur_cd_values, label='Baseline - 1NN-Accur CD', color='blue', marker='o', alpha=0.3)
axs[1, 0].plot(config1_iterations, config1_data['1NN-Accur'], label='Configuration 1 - 1NN-Accur CD', color='red', marker='x', alpha=0.3)
axs[1, 0].plot(config2_iterations, config2_data['1NN-Accur'], label='Configuration 2 - 1NN-Accur CD', color='green', marker='s')
axs[1, 0].set_xlabel('Iterations')
axs[1, 0].set_ylabel('1NN-Accur Chamfer Distance (CD)')
axs[1, 0].set_title('1NN-Accur Chamfer Distance')
axs[1, 0].legend()
axs[1, 0].grid(True)

# Jensen-Shannon Divergence
axs[1, 1].plot(baseline_iterations, baseline_jsd_values, label='Baseline - JSD', color='blue', marker='o', alpha=0.3)
axs[1, 1].plot(config1_iterations, config1_data['Jensen-Shannon'], label='Configuration 1 - JSD', color='red', marker='x', alpha=0.3)
axs[1, 1].plot(config2_iterations, config2_data['Jensen-Shannon'], label='Configuration 2 - JSD', color='green', marker='s')
axs[1, 1].set_xlabel('Iterations')
axs[1, 1].set_ylabel('Jensen-Shannon Divergence')
axs[1, 1].set_title('Jensen-Shannon Divergence')
axs[1, 1].legend()
axs[1, 1].grid(True)

# Add a note explaining the differences
fig.text(0.5, -0.1, 'Note: These plots represent validation metrics. The scale of Chamfer distance is different in the training script. '
                   'During the validation stage, a subset of the validation set (400 point clouds) is used, leading to potential differences in MMD scores.', 
         ha='center', wrap=True)

# Adjust layout
plt.tight_layout()
plt.savefig('Combined_Validation_Curves_Comparison_default_config_1_and_2.png', dpi=500)
plt.show()
